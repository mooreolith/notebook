// %%
class Counter {
  value = 0;
  count(){
    this.value++;
  }
}

c = new Counter();

c.count();
c.count();
c.count();

console.log(c.value);
// Out:
// 3
// undefined

// %%
c.count();
c.count();

console.log(c.value);
// Out:
// 5
// undefined
