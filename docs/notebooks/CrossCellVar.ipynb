// %%
class One { get num(){ return 1; }}

// %%
var one = new One(); // throws an error
// Out:
// ReferenceError, Line: 1: One is not defined

// %%
var Two = class Two { get num(){ return 2; }}

// %%
var two = new Two()
two.num
// Out:
// 2
