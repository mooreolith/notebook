// %%
// variables are local to the cell, unless you explicitly use global variables
One = class One { get num(){ return 1; }}
class Two { get num(){ return 2; }};

// %%
var one = new One(); // succeeds
console.log(one.num);
var two = new Two(); // throws a Reference Error
console.log(two.num);
// Out:
// 1
// ReferenceError, Line: 7: Two is not defined
