// %%
console.log("Hello,");
return "World!"

// %%
createDiv = document.createElement.bind(document, 'div');
const div = createDiv();
div.style.border = '1px solid #00beef';
div.style.display = 'flex';
div.style.justifyContent = 'center';
div.style.alignItems = 'center';
div.style.height = '100px';
div.style.color = 'orangered';
div.innerText = "Hello, World!"
return div;

// %%
return 1

// %%
return "This is a string";

// %%
return {xs: 1, ys: 2}

// %%
return [100, 102, 201, 200]

// %%
return JSON.stringify([100, 102, 201, 200]);

// %%
return null;

// %%
return undefined
