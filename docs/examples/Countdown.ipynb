// %%
output.style.fontSize = '144px';

let t = 10;
let countdown = setInterval( () => {
  if(t > 0){
    output.value = t;
    t = t - 1;
  }else{
    output.value = "Liftoff!";
    clearInterval( countdown )
  }
}, 1000 )
// Out:
// Liftoff!
